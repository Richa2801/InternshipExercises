# %% [markdown]
# # Webscraping

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from urllib.request import urlopen

# %%
from bs4 import BeautifulSoup

# %%
url = "http://www.hubertiming.com/results/2017GPTR10K"
html = urlopen(url)

# %%
soup = BeautifulSoup(html, "lxml")

# %%
text = soup.get_text()

# %%
rows = soup.find_all('tr')
list_rows = []
for row in rows:
    row_td = row.find_all('td')
    str_cells = str(row_td)
    cleantext = BeautifulSoup(str_cells, "lxml").get_text()
    list_rows.append(cleantext)

# %%
df = pd.DataFrame(list_rows)
df.head(10)
# Out:
#                                                    0
# 0                                                 []
# 1                                  [Finishers:, 577]
# 2                                       [Male:, 414]
# 3                                     [Female:, 163]
# 4                                                 []
# 5  [1, 814, \r\n\r\n                    JARED WIL...
# 6  [2, 573, \r\n\r\n                    NATHAN A ...
# 7  [3, 687, \r\n\r\n                    FRANCISCO...
# 8  [4, 623, \r\n\r\n                    PAUL MORR...
# 9  [5, 569, \r\n\r\n                    DEREK G O...

# %%
df1 = df[0].str.split(',', expand=True)
df1.head(10)
# Out:
#              0      1                                                  2  \
# 0           []   None                                               None
# 1  [Finishers:   577]                                               None
# 2       [Male:   414]                                               None
# 3     [Female:   163]                                               None
# 4           []   None                                               None
# 5           [1    814   \r\n\r\n                    JARED WILSON\r\n\...
# 6           [2    573   \r\n\r\n                    NATHAN A SUSTERSI...
# 7           [3    687   \r\n\r\n                    FRANCISCO MAYA\r\...
# 8           [4    623   \r\n\r\n                    PAUL MORROW\r\n\r...
# 9           [5    569   \r\n\r\n                    DEREK G OSBORNE\r...
#
#       3           4       5       6  \
# 0  None        None    None    None
# 1  None        None    None    None
# 2  None        None    None    None
# 3  None        None    None    None
# 4  None        None    None    None
# 5     M      TIGARD   36:21   36:24
# 6     M    PORTLAND   36:42   36:45
# 7     M    PORTLAND   37:44   37:48
# 8     M   BEAVERTON   38:34   38:37
# 9     M   HILLSBORO   39:21   39:24
#
#                                                    7
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                                  ]
# 6   \n\r\n                            INTEL TEAM ...
# 7                                                  ]
# 8                                                  ]
# 9   \n\r\n                            INTEL TEAM ...

# %%
df1[0] = df1[0].str.strip('[')
df1.head(10)
# Out:
#             0      1                                                  2     3  \
# 0           ]   None                                               None  None
# 1  Finishers:   577]                                               None  None
# 2       Male:   414]                                               None  None
# 3     Female:   163]                                               None  None
# 4           ]   None                                               None  None
# 5           1    814   \r\n\r\n                    JARED WILSON\r\n\...     M
# 6           2    573   \r\n\r\n                    NATHAN A SUSTERSI...     M
# 7           3    687   \r\n\r\n                    FRANCISCO MAYA\r\...     M
# 8           4    623   \r\n\r\n                    PAUL MORROW\r\n\r...     M
# 9           5    569   \r\n\r\n                    DEREK G OSBORNE\r...     M
#
#             4       5       6  \
# 0        None    None    None
# 1        None    None    None
# 2        None    None    None
# 3        None    None    None
# 4        None    None    None
# 5      TIGARD   36:21   36:24
# 6    PORTLAND   36:42   36:45
# 7    PORTLAND   37:44   37:48
# 8   BEAVERTON   38:34   38:37
# 9   HILLSBORO   39:21   39:24
#
#                                                    7
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                                  ]
# 6   \n\r\n                            INTEL TEAM ...
# 7                                                  ]
# 8                                                  ]
# 9   \n\r\n                            INTEL TEAM ...

# %%
col_labels = soup.find_all('th')
all_header = []
col_str = str(col_labels)
cleantext2 = BeautifulSoup(col_str, "lxml").get_text()
all_header.append(cleantext2)

# %%
df2 = pd.DataFrame(all_header)
df2.head()
# Out:
#                                                    0
# 0  [Place, Bib, Name, Gender, City, Chip Time, Gu...

# %%
df3 = df2[0].str.split(',', expand=True)
df3.head()
# Out:
#         0     1      2        3      4           5          6       7
# 0  [Place   Bib   Name   Gender   City   Chip Time   Gun Time   Team]

# %%
frames = [df3, df1]

df4 = pd.concat(frames)
df4.head(10)
# Out:
#             0      1                                                  2  \
# 0      [Place    Bib                                               Name
# 0           ]   None                                               None
# 1  Finishers:   577]                                               None
# 2       Male:   414]                                               None
# 3     Female:   163]                                               None
# 4           ]   None                                               None
# 5           1    814   \r\n\r\n                    JARED WILSON\r\n\...
# 6           2    573   \r\n\r\n                    NATHAN A SUSTERSI...
# 7           3    687   \r\n\r\n                    FRANCISCO MAYA\r\...
# 8           4    623   \r\n\r\n                    PAUL MORROW\r\n\r...
#
#          3           4           5          6  \
# 0   Gender        City   Chip Time   Gun Time
# 0     None        None        None       None
# 1     None        None        None       None
# 2     None        None        None       None
# 3     None        None        None       None
# 4     None        None        None       None
# 5        M      TIGARD       36:21      36:24
# 6        M    PORTLAND       36:42      36:45
# 7        M    PORTLAND       37:44      37:48
# 8        M   BEAVERTON       38:34      38:37
#
#                                                    7
# 0                                              Team]
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                                  ]
# 6   \n\r\n                            INTEL TEAM ...
# 7                                                  ]
# 8                                                  ]

# %%
df5 = df4.rename(columns=df4.iloc[0])
df5.head()
# Out:
#        [Place    Bib   Name   Gender   City   Chip Time   Gun Time   Team]
# 0      [Place    Bib   Name   Gender   City   Chip Time   Gun Time   Team]
# 0           ]   None   None     None   None        None       None    None
# 1  Finishers:   577]   None     None   None        None       None    None
# 2       Male:   414]   None     None   None        None       None    None
# 3     Female:   163]   None     None   None        None       None    None

# %%
df6 = df5.drop(df5.index[0])

# %%
df7 = df6.dropna(axis=0, how='any')

# %%
df7.rename(columns={'[Place': 'Place'},inplace=True)
df7.rename(columns={' Team]': 'Team'},inplace=True)
df7.head()
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#   Place   Bib                                               Name  Gender  \
# 5     1   814   \r\n\r\n                    JARED WILSON\r\n\...       M
# 6     2   573   \r\n\r\n                    NATHAN A SUSTERSI...       M
# 7     3   687   \r\n\r\n                    FRANCISCO MAYA\r\...       M
# 8     4   623   \r\n\r\n                    PAUL MORROW\r\n\r...       M
# 9     5   569   \r\n\r\n                    DEREK G OSBORNE\r...       M
#
#          City  Chip Time  Gun Time  \
# 5      TIGARD      36:21     36:24
# 6    PORTLAND      36:42     36:45
# 7    PORTLAND      37:44     37:48
# 8   BEAVERTON      38:34     38:37
# 9   HILLSBORO      39:21     39:24
#
#                                                 Team
# 5                                                  ]
# 6   \n\r\n                            INTEL TEAM ...
# 7                                                  ]
# 8                                                  ]
# 9   \n\r\n                            INTEL TEAM ...

# %%
df7.iloc[:,2] = df7.iloc[:,2].str.strip('\r\n\r\n ')
df7.Team = df7.Team.str.strip('\n\r\n')
df7.Team = df7.Team.str.strip('\r\n ]')
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df7.head()
# Out:
#   Place   Bib                Name  Gender        City  Chip Time  Gun Time  \
# 5     1   814        JARED WILSON       M      TIGARD      36:21     36:24
# 6     2   573  NATHAN A SUSTERSIC       M    PORTLAND      36:42     36:45
# 7     3   687      FRANCISCO MAYA       M    PORTLAND      37:44     37:48
# 8     4   623         PAUL MORROW       M   BEAVERTON      38:34     38:37
# 9     5   569     DEREK G OSBORNE       M   HILLSBORO      39:21     39:24
#
#            Team
# 5
# 6  INTEL TEAM F
# 7
# 8
# 9  INTEL TEAM F

# %% [markdown]
# ### Now we can work with this dataframe
